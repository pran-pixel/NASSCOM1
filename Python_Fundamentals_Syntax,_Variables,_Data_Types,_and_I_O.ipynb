# %% [markdown]
# <a href="https://colab.research.google.com/github/pran-pixel/NASSCOM1/blob/main/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python!")
if True:
    print("This is indented correctly.")
else:
    print("This won't run.")
# Out:
# Hello, Python!
# This is indented correctly.

# %%
name= "Alice"
age = 20
print("name", name)
print("age" , age)
name = 123
print("new name is:",name)
# Out:
# name Alice
# age 20
# new name is: 123

# %%
a = 3
print(type(a))
# Out:
# <class 'int'>

# %%
b = 3.14
print(type(b))
# Out:
# <class 'float'>

# %%
c = "Python"
print(type(c))
d = True
print(type(d))
e = [1, 2, 3, "four"]
print(type(e), e)
f = {"name": "Alice", "age": 25}
print(type(f), f)
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'Alice', 'age': 25}

# %%
user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Enter your age: 23
# You will be 24 next year.
