# %% [markdown]
# <a href="https://colab.research.google.com/github/pran-pixel/NASSCOM1/blob/main/Copy_of_Python_core_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")
# Task 1.1

raw_sensor_data = []

for i in range(100):

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    minimum, maximum = READING_RANGES[device_type]
    value = round(random.uniform(minimum, maximum), 2)

    reading = (timestamp, device_id, device_type, location, value)

    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:5]:
    print(reading)














    #task 1.2

temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })

#task 1.3

print(temperature_readings[:5])

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)

#task 1.4

device_stats = {}

# Initialize
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

# Update min and max
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    if value < current_min:
        current_min = value

    if value > current_max:
        current_max = value

    device_stats[device_type] = (current_min, current_max)

print(device_stats)

#task 1.5.1

sliced_readings_1 = raw_sensor_data[9:20]

print(sliced_readings_1)

sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_2)

#task 1.5.2

sample_string = "PythonProgrammingIsFun"

substring_1 = sample_string[6:17]

print(substring_1)

substring_2 = sample_string[5::-1]

print(substring_2)

#task 1.5.3

fifth_reading_device_type = raw_sensor_data[4][2]

print(fifth_reading_device_type)

device_type_suffix = fifth_reading_device_type[-6:]

print(device_type_suffix)

#task 2.1

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")


first_timestamp = datetime.datetime.strptime(raw_sensor_data[0][0], "%Y-%m-%d %H:%M:%S")
last_timestamp = datetime.datetime.strptime(raw_sensor_data[-1][0], "%Y-%m-%d %H:%M:%S")

duration = last_timestamp - first_timestamp

days = duration.days
hours = duration.seconds // 3600
minutes = (duration.seconds % 3600) // 60

print(f"Duration: {days} days, {hours} hours, {minutes} minutes")


random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print(random_values)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-19 15:50:20', 'DEV001', 'Humidity_Sensor', 'OfficeA', 54.06)
# ('2026-07-19 15:50:20', 'DEV002', 'Light_Sensor', 'Warehouse', 969.61)
# ('2026-07-19 15:50:20', 'DEV003', 'Pressure_Sensor', 'OfficeB', 1025.91)
# ('2026-07-19 15:50:20', 'DEV004', 'Light_Sensor', 'Lab1', 106.05)
# ('2026-07-19 15:50:20', 'DEV005', 'Light_Sensor', 'OfficeB', 723.23)
# [{'timestamp': '2026-07-19 15:50:20', 'device_id': 'DEV007', 'location': 'OfficeB', 'temperature_celsius': 20.95}, {'timestamp': '2026-07-19 15:50:20', 'device_id': 'DEV016', 'location': 'Warehouse', 'temperature_celsius': 25.92}, {'timestamp': '2026-07-19 15:50:20', 'device_id': 'DEV019', 'location': 'OfficeA', 'temperature_celsius': 25.68}, {'timestamp': '2026-07-19 15:50:20', 'device_id': 'DEV024', 'location': 'Lab1', 'temperature_celsius': 19.82}, {'timestamp': '2026-07-19 15:50:20', 'device_id': 'DEV029', 'location': 'OfficeA', 'temperature_celsius': 22.64}]
# {'OfficeA', 'OfficeB', 'Lab1', 'Lab2', 'Warehouse'}
# {'Temperature_Sensor': (19.82, 29.84), 'Humidity_Sensor': (30.88, 78.39), 'Pressure_Sensor': (983.32, 1026.79), 'Light_Sensor': (101.02, 996.36)}
# [('2026-07-19 15:50:20', 'DEV010', 'Humidity_Sensor', 'OfficeA', 37.56), ('2026-07-19 15:50:20', 'DEV011', 'Light_Sensor', 'Warehouse', 347.79), ('2026-07-19 15:50:20', 'DEV012', 'Light_Sensor', 'OfficeB', 634.86), ('2026-07-19 15:50:20', 'DEV013', 'Humidity_Sensor', 'Lab2', 39.43), ('2026-07-19 15:50:20', 'DEV014', 'Humidity_Sensor', 'OfficeB', 74.9), ('2026-07-19 15:50:20', 'DEV015', 'Pressure_Sensor', 'Lab2', 1022.96), ('2026-07-19 15:50:20', 'DEV016', 'Temperature_Sensor', 'Warehouse', 25.92), ('2026-07-19 15:50:20', 'DEV017', 'Light_Sensor', 'OfficeB', 961.94), ('2026-07-19 15:50:20', 'DEV018', 'Humidity_Sensor', 'OfficeA', 77.9), ('2026-07-19 15:50:20', 'DEV019', 'Temperature_Sensor', 'OfficeA', 25.68), ('2026-07-19 15:50:20', 'DEV020', 'Pressure_Sensor', 'Warehouse', 991.47)]
# [('2026-07-19 15:50:20', 'DEV001', 'Humidity_Sensor', 'OfficeA', 54.06), ('2026-07-19 15:50:20', 'DEV006', 'Light_Sensor', 'Lab1', 943.94), ('2026-07-19 15:50:20', 'DEV011', 'Light_Sensor', 'Warehouse', 347.79), ('2026-07-19 15:50:20', 'DEV016', 'Temperature_Sensor', 'Warehouse', 25.92), ('2026-07-19 15:50:20', 'DEV021', 'Light_Sensor', 'OfficeB', 116.58), ('2026-07-19 15:50:20', 'DEV026', 'Humidity_Sensor', 'OfficeA', 77.58), ('2026-07-19 15:50:20', 'DEV031', 'Light_Sensor', 'OfficeB', 970.04), ('2026-07-19 15:50:20', 'DEV036', 'Temperature_Sensor', 'Lab2', 27.1), ('2026-07-19 15:50:20', 'DEV041', 'Light_Sensor', 'Lab2', 848.25), ('2026-07-19 15:50:20', 'DEV046', 'Humidity_Sensor', 'Warehouse', 38.67), ('2026-07-19 15:50:20', 'DEV051', 'Temperature_Sensor', 'Lab2', 27.84), ('2026-07-19 15:50:20', 'DEV056', 'Humidity_Sensor', 'Warehouse', 34.06), ('2026-07-19 15:50:20', 'DEV061', 'Temperature_Sensor', 'OfficeA', 29.84), ('2026-07-19 15:50:20', 'DEV066', 'Pressure_Sensor', 'Lab1', 998.21), ('2026-07-19 15:50:20', 'DEV071', 'Temperature_Sensor', 'Warehouse', 24.83), ('2026-07-19 15:50:20', 'DEV076', 'Temperature_Sensor', 'Lab1', 25.45), ('2026-07-19 15:50:20', 'DEV081', 'Light_Sensor', 'OfficeB', 985.32), ('2026-07-19 15:50:20', 'DEV086', 'Temperature_Sensor', 'OfficeA', 24.19), ('2026-07-19 15:50:20', 'DEV091', 'Temperature_Sensor', 'Lab1', 20.75), ('2026-07-19 15:50:20', 'DEV096', 'Humidity_Sensor', 'Lab2', 36.62)]
# Programming
# nohtyP
# Light_Sensor
# Sensor
# Directory 'sensor_reports' created.
# Duration: 0 days, 0 hours, 0 minutes
# [140, 114, 123, 177, 198]
