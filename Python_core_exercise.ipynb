# %% [markdown]
# <a href="https://colab.research.google.com/github/pran-pixel/NASSCOM1/blob/main/Python_core_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}


raw_sensor_data = []

for i in range(100):

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    minimum, maximum = READING_RANGES[device_type]
    value = round(random.uniform(minimum, maximum), 2)

    reading = (timestamp, device_id, device_type, location, value)

    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:5]:
    print(reading)
















temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })

print(temperature_readings[:5])

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)


device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))


for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    if value < current_min:
        current_min = value

    if value > current_max:
        current_max = value

    device_stats[device_type] = (current_min, current_max)

print(device_stats)



sliced_readings_1 = raw_sensor_data[9:20]

print(sliced_readings_1)

sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_2)


sample_string = "PythonProgrammingIsFun"

substring_1 = sample_string[6:17]

print(substring_1)

substring_2 = sample_string[5::-1]

print(substring_2)



fifth_reading_device_type = raw_sensor_data[4][2]

print(fifth_reading_device_type)

device_type_suffix = fifth_reading_device_type[-6:]

print(device_type_suffix)



def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")


first_timestamp = datetime.datetime.strptime(raw_sensor_data[0][0], "%Y-%m-%d %H:%M:%S")
last_timestamp = datetime.datetime.strptime(raw_sensor_data[-1][0], "%Y-%m-%d %H:%M:%S")

duration = last_timestamp - first_timestamp

days = duration.days
hours = duration.seconds // 3600
minutes = (duration.seconds % 3600) // 60

print(f"Duration: {days} days, {hours} hours, {minutes} minutes")


random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print(random_values)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ('2026-07-20 03:49:00', 'DEV001', 'Humidity_Sensor', 'OfficeA', 38.53)
# ('2026-07-20 03:49:00', 'DEV002', 'Humidity_Sensor', 'OfficeB', 58.8)
# ('2026-07-20 03:49:00', 'DEV003', 'Pressure_Sensor', 'OfficeA', 981.0)
# ('2026-07-20 03:49:00', 'DEV004', 'Temperature_Sensor', 'Lab1', 29.41)
# ('2026-07-20 03:49:00', 'DEV005', 'Pressure_Sensor', 'OfficeA', 992.39)
# [{'timestamp': '2026-07-20 03:49:00', 'device_id': 'DEV004', 'location': 'Lab1', 'temperature_celsius': 29.41}, {'timestamp': '2026-07-20 03:49:00', 'device_id': 'DEV015', 'location': 'Warehouse', 'temperature_celsius': 23.8}, {'timestamp': '2026-07-20 03:49:00', 'device_id': 'DEV020', 'location': 'OfficeB', 'temperature_celsius': 28.4}, {'timestamp': '2026-07-20 03:49:00', 'device_id': 'DEV028', 'location': 'OfficeA', 'temperature_celsius': 28.37}, {'timestamp': '2026-07-20 03:49:00', 'device_id': 'DEV029', 'location': 'Lab2', 'temperature_celsius': 23.0}]
# {'Warehouse', 'OfficeB', 'OfficeA', 'Lab1', 'Lab2'}
# {'Temperature_Sensor': (18.8, 29.83), 'Humidity_Sensor': (31.26, 77.78), 'Pressure_Sensor': (981.0, 1028.75), 'Light_Sensor': (158.92, 978.09)}
# [('2026-07-20 03:49:00', 'DEV010', 'Humidity_Sensor', 'OfficeB', 39.2), ('2026-07-20 03:49:00', 'DEV011', 'Humidity_Sensor', 'Lab1', 57.48), ('2026-07-20 03:49:00', 'DEV012', 'Light_Sensor', 'Lab2', 232.59), ('2026-07-20 03:49:00', 'DEV013', 'Humidity_Sensor', 'OfficeA', 49.7), ('2026-07-20 03:49:00', 'DEV014', 'Humidity_Sensor', 'OfficeA', 66.01), ('2026-07-20 03:49:00', 'DEV015', 'Temperature_Sensor', 'Warehouse', 23.8), ('2026-07-20 03:49:00', 'DEV016', 'Humidity_Sensor', 'Lab2', 55.66), ('2026-07-20 03:49:00', 'DEV017', 'Humidity_Sensor', 'OfficeB', 33.73), ('2026-07-20 03:49:00', 'DEV018', 'Pressure_Sensor', 'OfficeA', 1007.35), ('2026-07-20 03:49:00', 'DEV019', 'Light_Sensor', 'Lab1', 217.9), ('2026-07-20 03:49:00', 'DEV020', 'Temperature_Sensor', 'OfficeB', 28.4)]
# [('2026-07-20 03:49:00', 'DEV001', 'Humidity_Sensor', 'OfficeA', 38.53), ('2026-07-20 03:49:00', 'DEV006', 'Pressure_Sensor', 'Lab2', 1025.27), ('2026-07-20 03:49:00', 'DEV011', 'Humidity_Sensor', 'Lab1', 57.48), ('2026-07-20 03:49:00', 'DEV016', 'Humidity_Sensor', 'Lab2', 55.66), ('2026-07-20 03:49:00', 'DEV021', 'Light_Sensor', 'Warehouse', 158.92), ('2026-07-20 03:49:00', 'DEV026', 'Pressure_Sensor', 'OfficeB', 1015.64), ('2026-07-20 03:49:00', 'DEV031', 'Light_Sensor', 'Lab1', 895.65), ('2026-07-20 03:49:00', 'DEV036', 'Temperature_Sensor', 'Lab1', 21.88), ('2026-07-20 03:49:00', 'DEV041', 'Pressure_Sensor', 'OfficeB', 997.09), ('2026-07-20 03:49:00', 'DEV046', 'Humidity_Sensor', 'Lab1', 42.93), ('2026-07-20 03:49:00', 'DEV051', 'Light_Sensor', 'OfficeA', 324.99), ('2026-07-20 03:49:00', 'DEV056', 'Temperature_Sensor', 'Lab1', 26.94), ('2026-07-20 03:49:00', 'DEV061', 'Light_Sensor', 'Lab2', 570.91), ('2026-07-20 03:49:00', 'DEV066', 'Light_Sensor', 'OfficeA', 976.33), ('2026-07-20 03:49:00', 'DEV071', 'Light_Sensor', 'OfficeA', 432.23), ('2026-07-20 03:49:00', 'DEV076', 'Humidity_Sensor', 'Lab2', 34.07), ('2026-07-20 03:49:00', 'DEV081', 'Light_Sensor', 'Warehouse', 716.42), ('2026-07-20 03:49:00', 'DEV086', 'Humidity_Sensor', 'OfficeB', 57.29), ('2026-07-20 03:49:00', 'DEV091', 'Light_Sensor', 'Lab1', 957.44), ('2026-07-20 03:49:00', 'DEV096', 'Temperature_Sensor', 'OfficeA', 29.79)]
# Programming
# nohtyP
# Pressure_Sensor
# Sensor
# Directory 'sensor_reports' created.
# Duration: 0 days, 0 hours, 0 minutes
# [133, 141, 111, 173, 140]
