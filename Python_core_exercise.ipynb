# %% [markdown]
# <a href="https://colab.research.google.com/github/pran-pixel/NASSCOM1/blob/main/Python_core_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}


raw_sensor_data = []

for i in range(100):

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    minimum, maximum = READING_RANGES[device_type]
    value = round(random.uniform(minimum, maximum), 2)

    reading = (timestamp, device_id, device_type, location, value)

    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:5]:
    print(reading)
















temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })

print(temperature_readings[:5])

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)


device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))


for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    if value < current_min:
        current_min = value

    if value > current_max:
        current_max = value

    device_stats[device_type] = (current_min, current_max)

print(device_stats)



sliced_readings_1 = raw_sensor_data[9:20]

print(sliced_readings_1)

sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_2)


sample_string = "PythonProgrammingIsFun"

substring_1 = sample_string[6:17]

print(substring_1)

substring_2 = sample_string[5::-1]

print(substring_2)



fifth_reading_device_type = raw_sensor_data[4][2]

print(fifth_reading_device_type)

device_type_suffix = fifth_reading_device_type[-6:]

print(device_type_suffix)



def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")


first_timestamp = datetime.datetime.strptime(raw_sensor_data[0][0], "%Y-%m-%d %H:%M:%S")
last_timestamp = datetime.datetime.strptime(raw_sensor_data[-1][0], "%Y-%m-%d %H:%M:%S")

duration = last_timestamp - first_timestamp

days = duration.days
hours = duration.seconds // 3600
minutes = (duration.seconds % 3600) // 60

print(f"Duration: {days} days, {hours} hours, {minutes} minutes")


random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print(random_values)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-19 15:39:23', 'DEV001', 'Humidity_Sensor', 'Lab1', 40.14)
# ('2026-07-19 15:39:23', 'DEV002', 'Pressure_Sensor', 'OfficeA', 1021.41)
# ('2026-07-19 15:39:23', 'DEV003', 'Humidity_Sensor', 'Lab1', 58.33)
# ('2026-07-19 15:39:23', 'DEV004', 'Light_Sensor', 'Lab2', 106.25)
# ('2026-07-19 15:39:23', 'DEV005', 'Pressure_Sensor', 'Lab2', 992.09)
# [{'timestamp': '2026-07-19 15:39:23', 'device_id': 'DEV007', 'location': 'Lab1', 'temperature_celsius': 29.56}, {'timestamp': '2026-07-19 15:39:23', 'device_id': 'DEV010', 'location': 'Warehouse', 'temperature_celsius': 24.93}, {'timestamp': '2026-07-19 15:39:23', 'device_id': 'DEV012', 'location': 'OfficeB', 'temperature_celsius': 20.64}, {'timestamp': '2026-07-19 15:39:23', 'device_id': 'DEV015', 'location': 'Warehouse', 'temperature_celsius': 28.32}, {'timestamp': '2026-07-19 15:39:23', 'device_id': 'DEV016', 'location': 'OfficeB', 'temperature_celsius': 27.84}]
# {'Warehouse', 'Lab1', 'OfficeB', 'OfficeA', 'Lab2'}
# {'Temperature_Sensor': (18.5, 29.91), 'Humidity_Sensor': (35.73, 79.0), 'Pressure_Sensor': (980.5, 1023.16), 'Light_Sensor': (106.25, 858.71)}
# [('2026-07-19 15:39:23', 'DEV010', 'Temperature_Sensor', 'Warehouse', 24.93), ('2026-07-19 15:39:23', 'DEV011', 'Light_Sensor', 'OfficeA', 194.83), ('2026-07-19 15:39:23', 'DEV012', 'Temperature_Sensor', 'OfficeB', 20.64), ('2026-07-19 15:39:23', 'DEV013', 'Pressure_Sensor', 'OfficeB', 983.89), ('2026-07-19 15:39:23', 'DEV014', 'Humidity_Sensor', 'Lab1', 70.07), ('2026-07-19 15:39:23', 'DEV015', 'Temperature_Sensor', 'Warehouse', 28.32), ('2026-07-19 15:39:23', 'DEV016', 'Temperature_Sensor', 'OfficeB', 27.84), ('2026-07-19 15:39:23', 'DEV017', 'Humidity_Sensor', 'Warehouse', 74.21), ('2026-07-19 15:39:23', 'DEV018', 'Temperature_Sensor', 'OfficeA', 21.52), ('2026-07-19 15:39:23', 'DEV019', 'Light_Sensor', 'OfficeB', 502.88), ('2026-07-19 15:39:23', 'DEV020', 'Humidity_Sensor', 'Lab1', 65.98)]
# [('2026-07-19 15:39:23', 'DEV001', 'Humidity_Sensor', 'Lab1', 40.14), ('2026-07-19 15:39:23', 'DEV006', 'Pressure_Sensor', 'Lab1', 989.98), ('2026-07-19 15:39:23', 'DEV011', 'Light_Sensor', 'OfficeA', 194.83), ('2026-07-19 15:39:23', 'DEV016', 'Temperature_Sensor', 'OfficeB', 27.84), ('2026-07-19 15:39:23', 'DEV021', 'Pressure_Sensor', 'Lab1', 991.29), ('2026-07-19 15:39:23', 'DEV026', 'Temperature_Sensor', 'Warehouse', 20.24), ('2026-07-19 15:39:23', 'DEV031', 'Humidity_Sensor', 'Lab2', 35.73), ('2026-07-19 15:39:23', 'DEV036', 'Humidity_Sensor', 'Lab1', 60.19), ('2026-07-19 15:39:23', 'DEV041', 'Pressure_Sensor', 'Lab1', 993.51), ('2026-07-19 15:39:23', 'DEV046', 'Temperature_Sensor', 'Lab1', 27.15), ('2026-07-19 15:39:23', 'DEV051', 'Light_Sensor', 'OfficeA', 820.33), ('2026-07-19 15:39:23', 'DEV056', 'Pressure_Sensor', 'OfficeA', 1010.25), ('2026-07-19 15:39:23', 'DEV061', 'Pressure_Sensor', 'Lab1', 983.3), ('2026-07-19 15:39:23', 'DEV066', 'Light_Sensor', 'Lab2', 733.52), ('2026-07-19 15:39:23', 'DEV071', 'Temperature_Sensor', 'OfficeA', 28.83), ('2026-07-19 15:39:23', 'DEV076', 'Temperature_Sensor', 'Lab1', 28.65), ('2026-07-19 15:39:23', 'DEV081', 'Humidity_Sensor', 'OfficeA', 36.48), ('2026-07-19 15:39:23', 'DEV086', 'Humidity_Sensor', 'OfficeB', 40.8), ('2026-07-19 15:39:23', 'DEV091', 'Temperature_Sensor', 'OfficeB', 29.91), ('2026-07-19 15:39:23', 'DEV096', 'Temperature_Sensor', 'OfficeA', 20.34)]
# Programming
# nohtyP
# Pressure_Sensor
# Sensor
# Directory 'sensor_reports' created.
# Duration: 0 days, 0 hours, 0 minutes
# [198, 173, 188, 121, 191]
